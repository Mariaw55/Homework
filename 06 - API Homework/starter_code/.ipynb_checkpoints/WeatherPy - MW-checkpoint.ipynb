# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# WeatherPy Observations
#
# Based on the 559 cities generated by CityPy, as the latitude of the cities moved closer to the Equator, latitide 0 degrees, the temperature increased and was warmer.  Additionally, humidity increased once cities were closer to the equator as well as north of it.  There was no signficant trend between latitudes near the equator having higher or lower windspeed as the data shows that regardless of latitude the windspeed were 10 MPH or less in majority of cities.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import json
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# %%
# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_data = response["name"]
        print(f"Processing Record {record} | {city_data}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skip and go to next...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=jamestown
# Processing Record 2 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=vila velha
# Processing Record 3 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=albany
# Processing Record 4 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=butaritari
# Processing Record 5 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=san cristobal
# Processing Record 6 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mataura
# Processing Record 7 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=margate
# Processing Record 8 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=tiksi
# Processing Record 9 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=cape town
# Processing Record 10 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ushuaia
# Processing Record 11 | Loanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=loanda
# Processing Record 12 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=provideniya
# Processing Record 13 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hobart
# City not found. Skip and go to next...
# Processing Record 14 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ayan
# Processing Record 15 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=rikitea
# Processing Record 16 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=tuktoyaktuk
# Processing Record 17 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nikolskoye
# Processing Record 18 | Boffa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=boffa
# Processing Record 19 | Jaslo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=jaslo
# Processing Record 20 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=punta arenas
# Processing Record 21 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=new norfolk
# Processing Record 22 | Santiago de Cao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=santiago de cao
# Processing Record 23 | Matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=matagami
# City not found. Skip and go to next...
# Processing Record 24 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hilo
# Processing Record 25 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=vaini
# Processing Record 26 | Butembo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=butembo
# Processing Record 27 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=busselton
# Processing Record 28 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hermanus
# Processing Record 29 | Boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=boyolangu
# City not found. Skip and go to next...
# City not found. Skip and go to next...
# Processing Record 30 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=namatanai
# Processing Record 31 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=barrow
# Processing Record 32 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=arraial do cabo
# Processing Record 33 | Dmitriyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=dmitriyevka
# Processing Record 34 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=chokurdakh
# Processing Record 35 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=port alfred
# Processing Record 36 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ambilobe
# Processing Record 37 | Martapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=martapura
# Processing Record 38 | Shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=shache
# Processing Record 39 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=qaanaaq
# Processing Record 40 | High Level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=high level
# Processing Record 41 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pisco
# Processing Record 42 | Mazagao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mazagao
# Processing Record 43 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=constitucion
# Processing Record 44 | Atbasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=atbasar
# Processing Record 45 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=carnarvon
# Processing Record 46 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bethel
# Processing Record 47 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=camacha
# Processing Record 48 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nome
# Processing Record 49 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=avarua
# Processing Record 50 | Koumac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=koumac
# Processing Record 51 | Abastumani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=abastumani
# Processing Record 52 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bredasdorp
# Processing Record 53 | Visby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=visby
# City not found. Skip and go to next...
# Processing Record 54 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kaitangata
# Processing Record 55 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bilma
# Processing Record 56 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=grindavik
# Processing Record 57 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=sisimiut
# City not found. Skip and go to next...
# Processing Record 58 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=atuona
# Processing Record 59 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hasaki
# Processing Record 60 | Monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=monrovia
# Processing Record 61 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=codrington
# Processing Record 62 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=upernavik
# Processing Record 63 | Poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=poya
# Processing Record 64 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nantucket
# Processing Record 65 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=clyde river
# Processing Record 66 | Humaita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=humaita
# Processing Record 67 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=severo-kurilsk
# Processing Record 68 | Elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=elko
# City not found. Skip and go to next...
# Processing Record 69 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bambous virieux
# Processing Record 70 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kalmunai
# Processing Record 71 | Tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=tecoanapa
# City not found. Skip and go to next...
# Processing Record 72 | Chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=chicama
# Processing Record 73 | Zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=zyryanka
# Processing Record 74 | Tierra Colorada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=tierra colorada
# Processing Record 75 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ahipara
# City not found. Skip and go to next...
# Processing Record 76 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=castro
# City not found. Skip and go to next...
# Processing Record 77 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=seoul
# City not found. Skip and go to next...
# Processing Record 78 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=geraldton
# City not found. Skip and go to next...
# Processing Record 79 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=dikson
# Processing Record 80 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ketchikan
# Processing Record 81 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=east london
# Processing Record 82 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=talnakh
# Processing Record 83 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=saint-joseph
# Processing Record 84 | Byron Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=byron bay
# Processing Record 85 | Rock Sound
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=rock sound
# Processing Record 86 | Mayskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mayskiy
# Processing Record 87 | Tshikapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=tshikapa
# Processing Record 88 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=norman wells
# Processing Record 89 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=tuatapere
# Processing Record 90 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=faanui
# Processing Record 91 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=georgetown
# Processing Record 92 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ilulissat
# Processing Record 93 | Haicheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=haicheng
# Processing Record 94 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=narsaq
# Processing Record 95 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kamenka
# Processing Record 96 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=lorengau
# Processing Record 97 | Araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=araouane
# Processing Record 98 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=vardo
# Processing Record 99 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=alofi
# City not found. Skip and go to next...
# Processing Record 100 | Redondela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=redondela
# Processing Record 101 | Svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=svetlogorsk
# Processing Record 102 | Dargaville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=dargaville
# Processing Record 103 | Maksatikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=maksatikha
# Processing Record 104 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=lebu
# Processing Record 105 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=portland
# Processing Record 106 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bonavista
# Processing Record 107 | Reconquista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=reconquista
# Processing Record 108 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=saskylakh
# Processing Record 109 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=torbay
# Processing Record 110 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=vostok
# Processing Record 111 | Ipira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ipira
# City not found. Skip and go to next...
# Processing Record 112 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=airai
# Processing Record 113 | Zhuzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=zhuzhou
# Processing Record 114 | Moose Factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=moose factory
# City not found. Skip and go to next...
# Processing Record 115 | Lubeck
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=lubeck
# Processing Record 116 | Abalak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=abalak
# Processing Record 117 | Zabol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=zabol
# Processing Record 118 | Ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ginir
# Processing Record 119 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bluff
# Processing Record 120 | Cordoba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=cordoba
# Processing Record 121 | Nizhniy Odes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nizhniy odes
# Processing Record 122 | Saint-Leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=saint-leu
# City not found. Skip and go to next...
# Processing Record 123 | Poltavka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=poltavka
# Processing Record 124 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=port elizabeth
# Processing Record 125 | Reims
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=reims
# Processing Record 126 | Benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=benguela
# Processing Record 127 | Altayskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=altayskoye
# Processing Record 128 | Sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=sibolga
# Processing Record 129 | Nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nabire
# Processing Record 130 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=harper
# Processing Record 131 | Langres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=langres
# Processing Record 132 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ponta do sol
# Processing Record 133 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=richards bay
# Processing Record 134 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hithadhoo
# Processing Record 135 | Mehran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mehran
# Processing Record 136 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kodiak
# Processing Record 137 | Smithfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=smithfield
# Processing Record 138 | Phan Thong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=phan thong
# Processing Record 139 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=port blair
# Processing Record 140 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=sitka
# Processing Record 141 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mar del plata
# Processing Record 142 | Nioro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nioro
# Processing Record 143 | Katangli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=katangli
# Processing Record 144 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=port-cartier
# Processing Record 145 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nanortalik
# Processing Record 146 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=salalah
# City not found. Skip and go to next...
# Processing Record 147 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=souillac
# Processing Record 148 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=abu dhabi
# Processing Record 149 | Lalsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=lalsk
# Processing Record 150 | Amarante
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=amarante
# City not found. Skip and go to next...
# City not found. Skip and go to next...
# Processing Record 151 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pevek
# Processing Record 152 | Privolnaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=privolnaya
# Processing Record 153 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hami
# Processing Record 154 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=husavik
# Processing Record 155 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=belaya gora
# Processing Record 156 | Grants
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=grants
# Processing Record 157 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=saint-philippe
# Processing Record 158 | Pahrump
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pahrump
# Processing Record 159 | San Vicente de Canete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=san vicente de canete
# Processing Record 160 | Corrales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=corrales
# Processing Record 161 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=yellowknife
# Processing Record 162 | Mikhaylovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mikhaylovka
# Processing Record 163 | Krasnovishersk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=krasnovishersk
# Processing Record 164 | Halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=halifax
# Processing Record 165 | Katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=katobu
# Processing Record 166 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mahebourg
# Processing Record 167 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=esperance
# Processing Record 168 | Caucaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=caucaia
# Processing Record 169 | Saint-Georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=saint-georges
# Processing Record 170 | Iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=iracoubo
# Processing Record 171 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ancud
# Processing Record 172 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kapaa
# Processing Record 173 | Alugan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=alugan
# Processing Record 174 | Raniganj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=raniganj
# Processing Record 175 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=chuy
# Processing Record 176 | Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=puerto escondido
# Processing Record 177 | Malayal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=malayal
# City not found. Skip and go to next...
# Processing Record 178 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=yulara
# Processing Record 179 | Yuli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=yuli
# Processing Record 180 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mount isa
# City not found. Skip and go to next...
# Processing Record 181 | Langen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=langen
# Processing Record 182 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=thompson
# Processing Record 183 | Davila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=davila
# City not found. Skip and go to next...
# Processing Record 184 | Whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=whitehorse
# Processing Record 185 | Vallenar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=vallenar
# Processing Record 186 | Apatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=apatou
# City not found. Skip and go to next...
# Processing Record 187 | Aalburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=aalburg
# Processing Record 188 | Saint-Paul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=saint-paul
# Processing Record 189 | Golden Gate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=golden gate
# Processing Record 190 | Kazerun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kazerun
# Processing Record 191 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=puerto ayora
# City not found. Skip and go to next...
# Processing Record 192 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=aklavik
# Processing Record 193 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=havre-saint-pierre
# Processing Record 194 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=maragogi
# Processing Record 195 | Plettenberg Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=plettenberg bay
# Processing Record 196 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pangnirtung
# Processing Record 197 | Ercis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ercis
# Processing Record 198 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bambanglipuro
# Processing Record 199 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=lavrentiya
# Processing Record 200 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kahului
# Processing Record 201 | Pemberton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pemberton
# Processing Record 202 | Baghdad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=baghdad
# Processing Record 203 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=coquimbo
# Processing Record 204 | Diamantina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=diamantina
# Processing Record 205 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pacific grove
# Processing Record 206 | Chapleau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=chapleau
# Processing Record 207 | Maxixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=maxixe
# Processing Record 208 | Vagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=vagay
# Processing Record 209 | Gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=gigmoto
# Processing Record 210 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=praia
# Processing Record 211 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=meulaboh
# Processing Record 212 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=makakilo city
# City not found. Skip and go to next...
# Processing Record 213 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=cherskiy
# Processing Record 214 | Ottawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ottawa
# Processing Record 215 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=tual
# City not found. Skip and go to next...
# Processing Record 216 | Bundaberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bundaberg
# Processing Record 217 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kavieng
# Processing Record 218 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=saint-pierre
# Processing Record 219 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bathsheba
# Processing Record 220 | Seidu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=seidu
# Processing Record 221 | Miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=miri
# Processing Record 222 | Batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=batagay
# Processing Record 223 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=dunedin
# Processing Record 224 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=port lincoln
# Processing Record 225 | Claresholm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=claresholm
# Processing Record 226 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=longyearbyen
# Processing Record 227 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hualmay
# City not found. Skip and go to next...
# Processing Record 228 | Bonfim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bonfim
# Processing Record 229 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=isangel
# Processing Record 230 | Amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=amahai
# Processing Record 231 | Eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=eureka
# Processing Record 232 | Noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=noumea
# Processing Record 233 | Samfya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=samfya
# Processing Record 234 | Tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=tabou
# Processing Record 235 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=vila franca do campo
# Processing Record 236 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mount gambier
# Processing Record 237 | Savannah Bight
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=savannah bight
# City not found. Skip and go to next...
# Processing Record 238 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ostrovnoy
# Processing Record 239 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nemuro
# Processing Record 240 | Dolores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=dolores
# Processing Record 241 | Urusha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=urusha
# Processing Record 242 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=rocha
# Processing Record 243 | Maiduguri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=maiduguri
# Processing Record 244 | San Mateo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=san mateo
# Processing Record 245 | Qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=qasigiannguit
# Processing Record 246 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=fairbanks
# Processing Record 247 | Manado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=manado
# City not found. Skip and go to next...
# Processing Record 248 | Morehead
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=morehead
# Processing Record 249 | Sao Felix do Xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=sao felix do xingu
# City not found. Skip and go to next...
# Processing Record 250 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=grand gaube
# Processing Record 251 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=maniitsoq
# Processing Record 252 | Develi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=develi
# Processing Record 253 | Hadishahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hadishahr
# Processing Record 254 | Hulan Ergi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hulan ergi
# Processing Record 255 | Healdsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=healdsburg
# Processing Record 256 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=lompoc
# Processing Record 257 | Mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mezen
# City not found. Skip and go to next...
# Processing Record 258 | Ampanihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ampanihy
# City not found. Skip and go to next...
# Processing Record 259 | Port Keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=port keats
# City not found. Skip and go to next...
# City not found. Skip and go to next...
# Processing Record 260 | Balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=balkhash
# Processing Record 261 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ribeira grande
# Processing Record 262 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=san patricio
# Processing Record 263 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=touros
# Processing Record 264 | Bay Roberts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bay roberts
# Processing Record 265 | Goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=goderich
# Processing Record 266 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=vao
# City not found. Skip and go to next...
# Processing Record 267 | Ouadda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ouadda
# Processing Record 268 | Lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=lima
# Processing Record 269 | Mundo Nuevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mundo nuevo
# Processing Record 270 | Khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=khandyga
# Processing Record 271 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=tura
# Processing Record 272 | Shymkent
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=shymkent
# City not found. Skip and go to next...
# City not found. Skip and go to next...
# City not found. Skip and go to next...
# City not found. Skip and go to next...
# Processing Record 273 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=khatanga
# Processing Record 274 | Orsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=orsk
# Processing Record 275 | Gibraleon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=gibraleon
# Processing Record 276 | Puerto Madryn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=puerto madryn
# Processing Record 277 | Moerai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=moerai
# Processing Record 278 | Fillan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=fillan
# Processing Record 279 | Yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=yumen
# Processing Record 280 | Mundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mundu
# City not found. Skip and go to next...
# Processing Record 281 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=olinda
# Processing Record 282 | Vysha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=vysha
# Processing Record 283 | Tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=tomatlan
# Processing Record 284 | Pavino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pavino
# Processing Record 285 | Kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kudahuvadhoo
# City not found. Skip and go to next...
# City not found. Skip and go to next...
# Processing Record 286 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ponta delgada
# Processing Record 287 | Xichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=xichang
# Processing Record 288 | Sarahan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=sarahan
# Processing Record 289 | Marshfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=marshfield
# City not found. Skip and go to next...
# Processing Record 290 | Kachiry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kachiry
# Processing Record 291 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=adrar
# Processing Record 292 | Ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ulaanbaatar
# Processing Record 293 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=beringovskiy
# Processing Record 294 | Port Augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=port augusta
# Processing Record 295 | Mocuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mocuba
# Processing Record 296 | Kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kutum
# Processing Record 297 | Yazman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=yazman
# Processing Record 298 | Hastings
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hastings
# Processing Record 299 | Abong Mbang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=abong mbang
# Processing Record 300 | La Palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=la palma
# City not found. Skip and go to next...
# Processing Record 301 | Rabo de Peixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=rabo de peixe
# Processing Record 302 | Iregszemcse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=iregszemcse
# Processing Record 303 | Tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=tezu
# Processing Record 304 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=caravelas
# Processing Record 305 | Melfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=melfi
# Processing Record 306 | Amantea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=amantea
# Processing Record 307 | Kanturk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kanturk
# Processing Record 308 | Marquard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=marquard
# Processing Record 309 | Serebryanyy Bor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=serebryanyy bor
# Processing Record 310 | Puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=puri
# Processing Record 311 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=egvekinot
# Processing Record 312 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=srednekolymsk
# Processing Record 313 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=saint george
# City not found. Skip and go to next...
# Processing Record 314 | High Prairie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=high prairie
# Processing Record 315 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=brae
# Processing Record 316 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bubaque
# Processing Record 317 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=inhambane
# Processing Record 318 | Leningradskiy
# ...
# Processing Record 454 | Manthani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=manthani
# Processing Record 455 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=flinders
# Processing Record 456 | Progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=progreso
# Processing Record 457 | Lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=lufilufi
# Processing Record 458 | Paracuru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=paracuru
# Processing Record 459 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mayo
# Processing Record 460 | Boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=boende
# Processing Record 461 | Baherden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=baherden
# Processing Record 462 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=sao joao da barra
# Processing Record 463 | Zhuhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=zhuhai
# Processing Record 464 | Sol-Iletsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=sol-iletsk
# City not found. Skip and go to next...
# Processing Record 465 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hobyo
# Processing Record 466 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=lata
# Processing Record 467 | Jiayuguan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=jiayuguan
# City not found. Skip and go to next...
# Processing Record 468 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=faya
# Processing Record 469 | Paragominas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=paragominas
# Processing Record 470 | Albion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=albion
# Processing Record 471 | Changde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=changde
# Processing Record 472 | Palora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=palora
# Processing Record 473 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=zhigansk
# Processing Record 474 | Puerto Baquerizo Moreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=puerto baquerizo moreno
# Processing Record 475 | Rehoboth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=rehoboth
# Processing Record 476 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=naze
# Processing Record 477 | Mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=mogadishu
# Processing Record 478 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=los llanos de aridane
# Processing Record 479 | Dumra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=dumra
# Processing Record 480 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=belmonte
# Processing Record 481 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=petropavlovsk-kamchatskiy
# Processing Record 482 | Boundiali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=boundiali
# Processing Record 483 | Dondo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=dondo
# Processing Record 484 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hamilton
# Processing Record 485 | Paraguacu Paulista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=paraguacu paulista
# Processing Record 486 | Port Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=port victoria
# Processing Record 487 | La Rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=la rioja
# Processing Record 488 | Doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=doha
# Processing Record 489 | Belem de Sao Francisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=belem de sao francisco
# Processing Record 490 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=acapulco
# Processing Record 491 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=fortuna
# Processing Record 492 | Emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=emerald
# Processing Record 493 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=port macquarie
# City not found. Skip and go to next...
# City not found. Skip and go to next...
# Processing Record 494 | Ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ulladulla
# Processing Record 495 | Shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=shelburne
# Processing Record 496 | Cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=cairns
# Processing Record 497 | Xixiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=xixiang
# Processing Record 498 | Almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=almaznyy
# Processing Record 499 | Marsh Harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=marsh harbour
# Processing Record 500 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=cockburn town
# Processing Record 501 | Rantepao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=rantepao
# Processing Record 502 | Benghazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=benghazi
# Processing Record 503 | Griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=griffith
# Processing Record 504 | Bedele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=bedele
# Processing Record 505 | Visnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=visnes
# Processing Record 506 | Touba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=touba
# Processing Record 507 | Aviemore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=aviemore
# Processing Record 508 | Sidi Ali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=sidi ali
# Processing Record 509 | Severnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=severnoye
# Processing Record 510 | Hollola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=hollola
# Processing Record 511 | Buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=buraydah
# Processing Record 512 | Alindao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=alindao
# Processing Record 513 | Omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=omboue
# Processing Record 514 | Nueva Germania
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nueva germania
# Processing Record 515 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=rio gallegos
# Processing Record 516 | Northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=northam
# Processing Record 517 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=vanimo
# Processing Record 518 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=luganville
# Processing Record 519 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=viedma
# Processing Record 520 | Pantai Remis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pantai remis
# Processing Record 521 | Dhadar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=dhadar
# Processing Record 522 | Saint-Prosper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=saint-prosper
# Processing Record 523 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nuuk
# Processing Record 524 | Heishan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=heishan
# Processing Record 525 | De Aar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=de aar
# Processing Record 526 | Pavlivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pavlivka
# Processing Record 527 | Werda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=werda
# Processing Record 528 | Pilar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pilar
# Processing Record 529 | Praia da Vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=praia da vitoria
# Processing Record 530 | Kerema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kerema
# Processing Record 531 | Nisia Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nisia floresta
# City not found. Skip and go to next...
# Processing Record 532 | Valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=valparaiso
# Processing Record 533 | Road Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=road town
# Processing Record 534 | Urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=urengoy
# Processing Record 535 | Slave Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=slave lake
# Processing Record 536 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=fort nelson
# Processing Record 537 | Myitkyina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=myitkyina
# Processing Record 538 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=karratha
# City not found. Skip and go to next...
# Processing Record 539 | Cua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=cua
# Processing Record 540 | Kushchevskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kushchevskaya
# Processing Record 541 | Abu Samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=abu samrah
# Processing Record 542 | Kungurtug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kungurtug
# Processing Record 543 | Dong Hoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=dong hoi
# Processing Record 544 | Royan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=royan
# Processing Record 545 | Iberia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=iberia
# Processing Record 546 | Champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=champerico
# City not found. Skip and go to next...
# Processing Record 547 | Ponnani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=ponnani
# Processing Record 548 | Pirovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pirovskoye
# Processing Record 549 | Porto Walter
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=porto walter
# City not found. Skip and go to next...
# Processing Record 550 | Abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=abha
# Processing Record 551 | Pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=pochutla
# Processing Record 552 | Todos Santos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=todos santos
# City not found. Skip and go to next...
# City not found. Skip and go to next...
# Processing Record 553 | Kefamenanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=kefamenanu
# Processing Record 554 | Gunjur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=gunjur
# Processing Record 555 | Nha Trang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=nha trang
# Processing Record 556 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=cidreira
# Processing Record 557 | Chivay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=chivay
# City not found. Skip and go to next...
# Processing Record 558 | Cesvaine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=cesvaine
# Processing Record 559 | Yining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6138d36ab6250c40666fc7b139659cee&q=yining

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(json.dumps(response, indent=2))
# Out:
# {
#   "coord": {
#     "lon": 114.56,
#     "lat": 29.04
#   },
#   "weather": [
#     {
#       "id": 800,
#       "main": "Clear",
#       "description": "clear sky",
#       "icon": "01n"
#     }
#   ],
#   "base": "stations",
#   "main": {
#     "temp": 71.97,
#     "pressure": 1011.59,
#     "humidity": 94,
#     "temp_min": 71.97,
#     "temp_max": 71.97,
#     "sea_level": 1011.59,
#     "grnd_level": 983.13
#   },
#   "wind": {
#     "speed": 1.25,
#     "deg": 70.623
#   },
#   "clouds": {
#     "all": 0
#   },
#   "dt": 1568144085,
#   "sys": {
#     "message": 0.0059,
#     "country": "CN",
#     "sunrise": 1568153061,
#     "sunset": 1568197998
#   },
#   "timezone": 28800,
#   "id": 1786538,
#   "name": "Yining",
#   "cod": 200
# }

# %%
# Create a dictonary with the lists generated
weather_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weather_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          559
# Cloudiness    559
# Country       559
# Date          559
# Humidity      559
# Lat           559
# Lng           559
# Max Temp      559
# Wind Speed    559
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv('output/weather_data.csv')

# Display data frame head 
weather_data.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Jamestown          42      AU  1568142865        59 -33.21  138.60
# 1     Vila Velha           0      BR  1568143273        58  -3.71  -38.60
# 2         Albany          90      US  1568142847        69  42.65  -73.75
# 3     Butaritari         100      KI  1568142970        92   3.07  172.79
# 4  San Cristobal          52      HN  1568143374        43  14.68  -86.92
#
#    Max Temp  Wind Speed
# 0     45.15        6.82
# 1     84.20       16.11
# 2     77.00        6.93
# 3     78.10       18.39
# 4     86.20        8.86

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (9/10/2019)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (9/10/2019)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (9/10/2019)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (9/10/2019)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
